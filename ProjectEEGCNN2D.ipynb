# %% [markdown]
# ### Final Project motor task classification using EEG Data

# %% [markdown]
# #### Importing necessary libraries

# %%
import numpy as np
import os
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/Shareddrives/C247
# Out:
# /content/gdrive/Shareddrives/C247

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten,Dropout
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Reshape
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras import activations

import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from load_data import *
from sklearn.model_selection import KFold

# %load_ext autoreload
# %autoreload 2

# %%
# %tensorflow_version 2.x
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# Loading full data
data_path = './project'

X_train_valid, y_train_valid, X_test, y_test, person_train_valid, person_test = load_full_data(data_path)

print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 22, 1000)
# Test data shape: (443, 22, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (443,)
# Person train/valid shape: (2115,)
# Person test shape: (443,)

# %%
## Adjusting the labels to {0,1,2,3}

# left hand - 0
# right hand - 1
# feet motion - 2
# tongue motion - 3

# labels are given as {769, 770, 771, 772}
base = y_train_valid.min()
y_train_valid-= base
y_test-= base

# %%
# Getting data for individual subjects

subject_data_train = split_data_by_subject(X_train_valid, y_train_valid, person_train_valid)
subject_data_test = split_data_by_subject(X_test, y_test, person_test)

# %%
# Changing of data dimensions

print ('Shape of training set: {}'.format(X_train_valid.shape))
print ('Shape of test set: {}'.format(X_test.shape))
print ('Shape of train labels: {}'.format(y_train_valid.shape))
print ('Shape of test labels: {}'.format(y_test.shape))

y_train_cv = to_categorical(y_train_valid, 4)
y_test_cv = to_categorical(y_test, 4)
print('Shape of training labels after categorical conversion:', y_train_cv.shape)
print('Shape of test labels after categorical conversion:', y_test_cv.shape)

# Adding width of the segment to be 1
x_train_cv = X_train_valid.reshape(X_train_valid.shape[0], X_train_valid.shape[1], X_train_valid.shape[2], 1)
x_test_cv = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)
print('Shape of training set after adding width info:',x_train_cv.shape)
print('Shape of test set after adding width info:',x_test_cv.shape)


# Reshaping the training and validation dataset
x_train_cv = np.swapaxes(x_train_cv, 1,3)
x_train_cv = np.swapaxes(x_train_cv, 1,2)

x_test_cv = np.swapaxes(x_test_cv, 1,3)
x_test_cv = np.swapaxes(x_test_cv, 1,2)
print('Shape of training set after dimension reshaping:',x_train_cv.shape)

print('Shape of test set after dimension reshaping:',x_test_cv.shape)
# Out:
# Shape of training set: (2115, 22, 1000)
# Shape of test set: (443, 22, 1000)
# Shape of train labels: (2115,)
# Shape of test labels: (443,)
# Shape of training labels after categorical conversion: (2115, 4)
# Shape of test labels after categorical conversion: (443, 4)
# Shape of training set after adding width info: (2115, 22, 1000, 1)
# Shape of test set after adding width info: (443, 22, 1000, 1)
# Shape of training set after dimension reshaping: (2115, 1000, 1, 22)
# Shape of test set after dimension reshaping: (443, 1000, 1, 22)

# %%
def data_prep(X,y,window_size,sub_sample,average,noise):
    # N,H,W,C ----- N,1000,1,22
    total_X = None
    total_y = None
    X = X[:,0:window_size,:,:]
    Xi = X
    X = np.transpose(X, (0,2, 3, 1))
    # Trimming the data (sample,22,1000) -> (sample,22,500)
    
    print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,1000) -> (sample,22,500/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], X.shape[2],-1, sub_sample), axis=4)   # N,W,C,H/sub_sample
    
    X_max = np.transpose(X_max, (0,3,1, 2))
    
    total_X = X_max
    total_y = y
    print('Shape of X after maxpooling:',total_X.shape,y.shape)
    
    # Averaging + noise 
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], X.shape[2],-1, sub_sample), axis=4)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    X_average = np.transpose(X_average, (0,3,1, 2))

    total_X = np.vstack((total_X, X_average))
    total_y = np.vstack((total_y, y))
    print('Shape of X after averaging+noise and concatenating:',total_X.shape,y.shape)
    
    # Subsampling
    
    for i in range(sub_sample):
        
        X_subsample = Xi[:,i::sub_sample, :, :] + \
                            (np.random.normal(0.0, 0.5, Xi[:,i::sub_sample, :, :].shape) if noise else 0.0)
            
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.vstack((total_y, y))
        
    
    print('Shape of X after subsampling and concatenating:',total_X.shape,y.shape)
    return total_X,total_y

# %% [markdown]
# #Building 2D CNN

# %%
from project.helpers import *

# %%
X_train, X_val, y_train, y_val = train_test_split(x_train_cv, y_train_cv, test_size=0.2, random_state=42)

# %%
tf.keras.backend.clear_session()

# %%
window_size = 500
print(X_train.shape,y_train.shape)
# X_train_dp,y_train_dp = data_prep(X_train,y_train,window_size,2,2,True)
X_train_grv = conv2DPrepreprocessing(X_train,5)
y_train_grv = y_train
print(X_train_grv.shape,y_train_grv.shape)
# Out:
# (1692, 1000, 1, 22) (1692, 4)
# (1692, 5, 200, 22) (1692, 4)

# %%
print(X_val.shape,y_val.shape)
# X_val_dp,y_val_dp = data_prep(X_val,y_val,window_size,2,2,True)
X_val_grv = conv2DPrepreprocessing(X_val,5)
y_val_grv = y_val
print(X_val_grv.shape,y_val_grv.shape)
# Out:
# (423, 1000, 1, 22) (423, 4)
# (423, 5, 200, 22) (423, 4)

# %%
print(x_test_cv.shape,y_test_cv.shape)
# x_test_dp,y_test_dp = data_prep(x_test_cv,y_test_cv,window_size,2,2,True)
x_test_grv = conv2DPrepreprocessing(x_test_cv,5)
y_test_grv = y_test_cv
print(x_test_grv.shape,y_test_grv.shape)
# Out:
# (443, 1000, 1, 22) (443, 4)
# (443, 5, 200, 22) (443, 4)

# %%
# import tensorflow as tf
from tensorflow.keras.layers import PReLU
import tensorflow

# %%
# Building the CNN model using sequential class
tf.keras.backend.clear_session()
basic_cnn_model2d = Sequential()

# Conv. block 1
basic_cnn_model2d.add(Conv2D(filters=16, kernel_size=(3,7), padding='same', activation='elu', input_shape=(5, 200, 22)))
basic_cnn_model2d.add(MaxPooling2D(pool_size=(2,2), padding='same')) # Read the keras documentation
basic_cnn_model2d.add(BatchNormalization())
basic_cnn_model2d.add(Dropout(0.5))

# Conv. block 2
basic_cnn_model2d.add(Conv2D(filters=32, kernel_size=(3,7), padding='same', activation='elu'))
basic_cnn_model2d.add(MaxPooling2D(pool_size=(2,2), padding='same'))
basic_cnn_model2d.add(BatchNormalization())
basic_cnn_model2d.add(Dropout(0.5))

# Conv. block 3
basic_cnn_model2d.add(Conv2D(filters=64, kernel_size=(3,7), padding='same', activation='elu'))
basic_cnn_model2d.add(MaxPooling2D(pool_size=(2,2), padding='same'))
basic_cnn_model2d.add(BatchNormalization())
basic_cnn_model2d.add(Dropout(0.5))

# Conv. block 4
basic_cnn_model2d.add(Conv2D(filters=128, kernel_size=(3,7), padding='same', activation='elu'))
basic_cnn_model2d.add(MaxPooling2D(pool_size=(2,2), padding='same'))
basic_cnn_model2d.add(BatchNormalization())
basic_cnn_model2d.add(Dropout(0.5))

# Output layer with Softmax activation
basic_cnn_model2d.add(Flatten()) # Flattens the input
basic_cnn_model2d.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation


# Printing the model summary
basic_cnn_model2d.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 5, 200, 16)        7408
#
#  max_pooling2d (MaxPooling2D  (None, 3, 100, 16)       0
#  )
#
#  batch_normalization (BatchN  (None, 3, 100, 16)       64
#  ormalization)
#
#  dropout (Dropout)           (None, 3, 100, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 3, 100, 32)        10784
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 50, 32)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 2, 50, 32)        128
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 2, 50, 32)         0
#
#  conv2d_2 (Conv2D)           (None, 2, 50, 64)         43072
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 25, 64)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 1, 25, 64)        256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 1, 25, 64)         0
#
#  conv2d_3 (Conv2D)           (None, 1, 25, 128)        172160
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 13, 128)       0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 1, 13, 128)       512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 1, 13, 128)        0
#
#  flatten (Flatten)           (None, 1664)              0
#
#  dense (Dense)               (None, 4)                 6660
#
# =================================================================
# Total params: 241,044
# Trainable params: 240,564
# Non-trainable params: 480
# _________________________________________________________________

# %%
# Model parameters
learning_rate = 1e-5
epochs = 50
cnn_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# %%
basic_cnn_model2d.compile(loss='categorical_crossentropy',
                 optimizer=cnn_optimizer,
                 metrics=['accuracy'])

# Training and validating the model
basic_cnn_model_results_2d = basic_cnn_model2d.fit(X_train_grv,
             y_train_grv,
             batch_size=64,
             epochs=epochs,
             validation_data=(X_val_grv, y_val_grv), verbose=True)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.3439 - accuracy: 0.8682 - val_loss: 0.8673 - val_accuracy: 0.6856
# Epoch 2/50
# 27/27 [==============================] - 0s 13ms/step - loss: 0.3595 - accuracy: 0.8570 - val_loss: 0.8655 - val_accuracy: 0.6879
# Epoch 3/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3300 - accuracy: 0.8729 - val_loss: 0.8620 - val_accuracy: 0.6903
# Epoch 4/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3304 - accuracy: 0.8729 - val_loss: 0.8626 - val_accuracy: 0.6903
# Epoch 5/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3517 - accuracy: 0.8623 - val_loss: 0.8589 - val_accuracy: 0.6903
# Epoch 6/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3485 - accuracy: 0.8688 - val_loss: 0.8657 - val_accuracy: 0.6856
# Epoch 7/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3379 - accuracy: 0.8717 - val_loss: 0.8619 - val_accuracy: 0.6879
# Epoch 8/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3473 - accuracy: 0.8682 - val_loss: 0.8579 - val_accuracy: 0.6927
# Epoch 9/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3595 - accuracy: 0.8593 - val_loss: 0.8550 - val_accuracy: 0.6950
# Epoch 10/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3483 - accuracy: 0.8652 - val_loss: 0.8528 - val_accuracy: 0.6974
# Epoch 11/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3466 - accuracy: 0.8641 - val_loss: 0.8556 - val_accuracy: 0.6974
# Epoch 12/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3587 - accuracy: 0.8611 - val_loss: 0.8529 - val_accuracy: 0.6950
# Epoch 13/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3667 - accuracy: 0.8552 - val_loss: 0.8542 - val_accuracy: 0.6950
# Epoch 14/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3430 - accuracy: 0.8694 - val_loss: 0.8507 - val_accuracy: 0.6879
# Epoch 15/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3372 - accuracy: 0.8747 - val_loss: 0.8531 - val_accuracy: 0.6950
# Epoch 16/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3486 - accuracy: 0.8706 - val_loss: 0.8608 - val_accuracy: 0.6950
# Epoch 17/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3392 - accuracy: 0.8706 - val_loss: 0.8607 - val_accuracy: 0.6903
# Epoch 18/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3359 - accuracy: 0.8741 - val_loss: 0.8598 - val_accuracy: 0.6903
# Epoch 19/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3312 - accuracy: 0.8723 - val_loss: 0.8593 - val_accuracy: 0.6879
# Epoch 20/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3199 - accuracy: 0.8735 - val_loss: 0.8618 - val_accuracy: 0.6950
# Epoch 21/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3284 - accuracy: 0.8647 - val_loss: 0.8595 - val_accuracy: 0.6927
# Epoch 22/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3447 - accuracy: 0.8712 - val_loss: 0.8563 - val_accuracy: 0.6927
# Epoch 23/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3283 - accuracy: 0.8777 - val_loss: 0.8587 - val_accuracy: 0.6927
# Epoch 24/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3645 - accuracy: 0.8623 - val_loss: 0.8521 - val_accuracy: 0.6950
# Epoch 25/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3473 - accuracy: 0.8712 - val_loss: 0.8560 - val_accuracy: 0.6927
# Epoch 26/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3588 - accuracy: 0.8599 - val_loss: 0.8588 - val_accuracy: 0.6879
# Epoch 27/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3505 - accuracy: 0.8599 - val_loss: 0.8597 - val_accuracy: 0.6879
# Epoch 28/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.3253 - accuracy: 0.8794 - val_loss: 0.8605 - val_accuracy: 0.6903
# Epoch 29/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3274 - accuracy: 0.8753 - val_loss: 0.8650 - val_accuracy: 0.6879
# Epoch 30/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3404 - accuracy: 0.8747 - val_loss: 0.8589 - val_accuracy: 0.6903
# Epoch 31/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3437 - accuracy: 0.8676 - val_loss: 0.8612 - val_accuracy: 0.6903
# Epoch 32/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3596 - accuracy: 0.8564 - val_loss: 0.8556 - val_accuracy: 0.6903
# Epoch 33/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3547 - accuracy: 0.8735 - val_loss: 0.8581 - val_accuracy: 0.6950
# Epoch 34/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3798 - accuracy: 0.8570 - val_loss: 0.8575 - val_accuracy: 0.6950
# Epoch 35/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3416 - accuracy: 0.8682 - val_loss: 0.8634 - val_accuracy: 0.6927
# Epoch 36/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3460 - accuracy: 0.8700 - val_loss: 0.8620 - val_accuracy: 0.6927
# Epoch 37/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3398 - accuracy: 0.8771 - val_loss: 0.8618 - val_accuracy: 0.6927
# Epoch 38/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3407 - accuracy: 0.8741 - val_loss: 0.8563 - val_accuracy: 0.6950
# Epoch 39/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3447 - accuracy: 0.8700 - val_loss: 0.8552 - val_accuracy: 0.6927
# Epoch 40/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3322 - accuracy: 0.8717 - val_loss: 0.8610 - val_accuracy: 0.6903
# Epoch 41/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3221 - accuracy: 0.8694 - val_loss: 0.8598 - val_accuracy: 0.6950
# Epoch 42/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3384 - accuracy: 0.8759 - val_loss: 0.8536 - val_accuracy: 0.6950
# Epoch 43/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3261 - accuracy: 0.8794 - val_loss: 0.8553 - val_accuracy: 0.6927
# Epoch 44/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3570 - accuracy: 0.8700 - val_loss: 0.8576 - val_accuracy: 0.6927
# Epoch 45/50
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3537 - accuracy: 0.8605 - val_loss: 0.8525 - val_accuracy: 0.6950
# Epoch 46/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3296 - accuracy: 0.8806 - val_loss: 0.8486 - val_accuracy: 0.6950
# Epoch 47/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3495 - accuracy: 0.8717 - val_loss: 0.8540 - val_accuracy: 0.6927
# Epoch 48/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3240 - accuracy: 0.8806 - val_loss: 0.8581 - val_accuracy: 0.6950
# Epoch 49/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3449 - accuracy: 0.8706 - val_loss: 0.8511 - val_accuracy: 0.6974
# Epoch 50/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.3306 - accuracy: 0.8723 - val_loss: 0.8479 - val_accuracy: 0.6974

# %%
## Testing the basic CNN model

cnn_score = basic_cnn_model2d.evaluate(x_test_grv, y_test_grv, verbose=0)
print('Test accuracy of the basic CNN model:',cnn_score[1])
# Out:
# Test accuracy of the basic CNN model: 0.7200902700424194
